# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

from PIL import Image

# %%
pic = Image.open('./CourseResources/DATA/00-puppy.jpg')

# %%
pic_array = np.array(pic)
pic_array.shape # H , W, RGB
# Out:
# (1300, 1950, 3)

# %%
# help(plt)
plt.imshow(pic_array) # or pass in pic instead

# %%
# Display image as red
red_pic = np.array(pic.copy())
plt.imshow(red_pic)

# %%
# all row, and columns,  and ONLY Green in R(0), G(1) , B(2)

plt.imshow(red_pic[:,:,1])

# %%
plt.imshow(red_pic[:,:,1], cmap='gray')
